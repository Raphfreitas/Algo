# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
mj = pd.read_csv('./Data/jordan_career.csv'); 

for i in range(len(mj)) :
    mj.age[i] = mj.age[i][0:2]
mj

#la problèmatique est : mon client souhaite savoir qui est le GOAT (Greatest Of All time) entre Lebron James et Michael Jordan
# Out:
# <ipython-input-72-bc0c2dae11c5>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mj.age[i] = mj.age[i][0:2]
#       game        date age team  opp   result     mp  fg  fga    fgp  ...  \
# 0        1  1984-10-26  21  CHI  WSB  W (+16)  40:00   5   16  0.313  ...
# 1        2  1984-10-27  21  CHI  MIL   L (-2)  34:00   8   13  0.615  ...
# 2        3  1984-10-29  21  CHI  MIL   W (+6)  34:00  13   24  0.542  ...
# 3        4  1984-10-30  21  CHI  KCK   W (+5)  36:00   8   21  0.381  ...
# 4        5  1984-11-01  21  CHI  DEN  L (-16)  33:00   7   15  0.467  ...
# ...    ...         ...  ..  ...  ...      ...    ...  ..  ...    ...  ...
# 1067    78  2003-04-09  40  WAS  BOS   L (-4)  43:00   8   17  0.471  ...
# 1068    79  2003-04-11  40  WAS  MIA   W (+4)  40:00  11   26  0.423  ...
# ...

# %%
lb = pd.read_csv('./Data/lebron_career.csv'); 
for i in range(len(lb)) :
    lb.age[i] = lb.age[i][0:2]
lb
# Out:
# <ipython-input-73-92709bf26dad>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lb.age[i] = lb.age[i][0:2]
#       game        date age team  opp   result     mp  fg  fga    fgp  ...  \
# 0        1  2003-10-29  18  CLE  SAC  L (-14)  42:00  12   20  0.600  ...
# 1        2  2003-10-30  18  CLE  PHO   L (-9)  41:00   8   17  0.471  ...
# 2        3  2003-11-01  18  CLE  POR  L (-19)  39:00   3   12  0.250  ...
# 3        4  2003-11-05  18  CLE  DEN   L (-4)  41:00   3   11  0.273  ...
# 4        5  2003-11-07  18  CLE  IND   L (-1)  44:00   8   18  0.444  ...
# ...    ...         ...  ..  ...  ...      ...    ...  ..  ...    ...  ...
# 1127    67  2018-03-13  33  CLE  PHO  W (+22)  33:13   7   14  0.500  ...
# 1128    68  2018-03-15  33  CLE  POR   L (-8)  41:05  15   25  0.600  ...
# ...

# %%
mj.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1072 entries, 0 to 1071
# Data columns (total 26 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   game        1072 non-null   int64
#  1   date        1072 non-null   object
#  2   age         1072 non-null   object
#  3   team        1072 non-null   object
#  4   opp         1072 non-null   object
#  5   result      1072 non-null   object
#  6   mp          1072 non-null   object
#  7   fg          1072 non-null   int64
#  8   fga         1072 non-null   int64
#  9   fgp         1072 non-null   float64
#  10  three       1072 non-null   int64
#  11  threeatt    1072 non-null   int64
#  12  threep      742 non-null    float64
#  13  ft          1072 non-null   int64
#  14  fta         1072 non-null   int64
#  15  ftp         1042 non-null   float64
#  16  orb         1072 non-null   int64
#  17  drb         1072 non-null   int64
#  18  trb         1072 non-null   int64
# ...

# %%
lb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1132 entries, 0 to 1131
# Data columns (total 26 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   game        1132 non-null   int64
#  1   date        1132 non-null   object
#  2   age         1132 non-null   object
#  3   team        1132 non-null   object
#  4   opp         1132 non-null   object
#  5   result      1132 non-null   object
#  6   mp          1132 non-null   object
#  7   fg          1132 non-null   int64
#  8   fga         1132 non-null   int64
#  9   fgp         1132 non-null   float64
#  10  three       1132 non-null   int64
#  11  threeatt    1132 non-null   int64
#  12  threep      1092 non-null   float64
#  13  ft          1132 non-null   int64
#  14  fta         1132 non-null   int64
#  15  ftp         1120 non-null   float64
#  16  orb         1132 non-null   int64
#  17  drb         1132 non-null   int64
#  18  trb         1132 non-null   int64
# ...

# %%
mj.tail()
# Out:
#       game        date age team  opp   result     mp  fg  fga    fgp  ...  \
# 1067    78  2003-04-09  40  WAS  BOS   L (-4)  43:00   8   17  0.471  ...
# 1068    79  2003-04-11  40  WAS  MIA   W (+4)  40:00  11   26  0.423  ...
# 1069    80  2003-04-12  40  WAS  ATL   L (-1)  30:00   8   16  0.500  ...
# 1070    81  2003-04-14  40  WAS  NYK  L (-14)  37:00   9   22  0.409  ...
# 1071    82  2003-04-16  40  WAS  PHI  L (-20)  28:00   6   15  0.400  ...
#
#       orb  drb  trb  ast  stl  blk  tov  pts  game_score  minus_plus
# 1067    0   10   10    1    2    0    1   21        16.2         NaN
# 1068    1    1    2    4    2    0    1   25        15.2         NaN
# 1069    2    6    8    6    1    1    2   17        14.5         NaN
# 1070    1    7    8    1    1    0    2   21        11.3         NaN
# 1071    0    4    4    4    0    0    2   15         8.5         NaN
#
# [5 rows x 26 columns]

# %%
mj.head()
# Out:
#    game        date age team  opp   result     mp  fg  fga    fgp  ...  orb  \
# 0     1  1984-10-26  21  CHI  WSB  W (+16)  40:00   5   16  0.313  ...    1
# 1     2  1984-10-27  21  CHI  MIL   L (-2)  34:00   8   13  0.615  ...    3
# 2     3  1984-10-29  21  CHI  MIL   W (+6)  34:00  13   24  0.542  ...    2
# 3     4  1984-10-30  21  CHI  KCK   W (+5)  36:00   8   21  0.381  ...    2
# 4     5  1984-11-01  21  CHI  DEN  L (-16)  33:00   7   15  0.467  ...    3
#
#    drb  trb  ast  stl  blk  tov  pts  game_score  minus_plus
# 0    5    6    7    2    4    5   16        12.5         NaN
# 1    2    5    5    2    1    3   21        19.4         NaN
# 2    2    4    5    6    2    3   37        32.9         NaN
# 3    2    4    5    3    1    6   25        14.7         NaN
# 4    2    5    5    1    1    2   17        13.2         NaN
#
# [5 rows x 26 columns]

# %%
lb.tail()
# Out:
#       game        date age team  opp   result     mp  fg  fga    fgp  ...  \
# 1127    67  2018-03-13  33  CLE  PHO  W (+22)  33:13   7   14  0.500  ...
# 1128    68  2018-03-15  33  CLE  POR   L (-8)  41:05  15   25  0.600  ...
# 1129    69  2018-03-17  33  CLE  CHI   W (+5)  39:53  15   26  0.577  ...
# 1130    70  2018-03-19  33  CLE  MIL   W (+7)  40:01  16   29  0.552  ...
# 1131    71  2018-03-21  33  CLE  TOR   W (+3)  39:24  11   19  0.579  ...
#
#       orb  drb  trb  ast  stl  blk  tov  pts  game_score  minus_plus
# 1127    0   12   12   11    3    2    5   28        30.1          23
# 1128    0   14   14    6    2    3    6   35        26.4          -3
# 1129    1   12   13   12    1    2    6   33        27.5          -4
# 1130    5    7   12   10    2    1    6   40        33.4           4
# 1131    1    6    7   17    1    0    0   35        39.9          12
#
# [5 rows x 26 columns]

# %%
lb.head()
# Out:
#    game        date age team  opp   result     mp  fg  fga    fgp  ...  orb  \
# 0     1  2003-10-29  18  CLE  SAC  L (-14)  42:00  12   20  0.600  ...    2
# 1     2  2003-10-30  18  CLE  PHO   L (-9)  41:00   8   17  0.471  ...    2
# 2     3  2003-11-01  18  CLE  POR  L (-19)  39:00   3   12  0.250  ...    0
# 3     4  2003-11-05  18  CLE  DEN   L (-4)  41:00   3   11  0.273  ...    2
# 4     5  2003-11-07  18  CLE  IND   L (-1)  44:00   8   18  0.444  ...    0
#
#    drb  trb  ast  stl  blk  tov  pts  game_score  minus_plus
# 0    4    6    9    4    0    2   25        24.7          -9
# 1   10   12    8    1    0    7   21        14.7          -3
# 2    4    4    6    2    0    2    8         5.0         -21
# 3    9   11    7    2    3    2    7        11.2          -3
# 4    5    5    3    0    0    7   23         9.0          -7
#
# [5 rows x 26 columns]

# %%
sns.regplot(x=mj["age"], y=mj["pts"],fit_reg=False)
plt.xlim()
plt.show()

# %%
sns.regplot(x=lb["age"], y=lb["pts"], fit_reg=False)
plt.show()

# %%
sns.displot(x="game_score",data=mj)

# %%
sns.displot(x="game_score",data=lb)

# %%
corr = mj.corr()
corr
# Out:
#                 game        fg       fga       fgp     three  threeatt  \
# game        1.000000  0.057520  0.009048  0.071741  0.034824  0.061423
# fg          0.057520  1.000000  0.784091  0.625907  0.179908  0.188724
# fga         0.009048  0.784091  1.000000  0.040850  0.098978  0.229746
# fgp         0.071741  0.625907  0.040850  1.000000  0.171696  0.036171
# three       0.034824  0.179908  0.098978  0.171696  1.000000  0.764969
# threeatt    0.061423  0.188724  0.229746  0.036171  0.764969  1.000000
# threep      0.006214  0.127906 -0.032516  0.269958  0.706942  0.231468
# ft          0.040261  0.273134  0.295626  0.080015 -0.089044 -0.045932
# fta         0.033602  0.273488  0.305117  0.072894 -0.101268 -0.056491
# ftp         0.003261  0.071794  0.047466  0.053656  0.029500  0.032183
# orb         0.006489  0.147968  0.256483 -0.069647 -0.031369  0.041165
# drb         0.033117  0.070266  0.096196  0.006263  0.090614  0.086532
# ...

# %%
sns.heatmap(corr,annot=True)
# Out:
# <AxesSubplot:>
